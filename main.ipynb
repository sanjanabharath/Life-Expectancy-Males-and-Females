# %%
# !pip install pandas
# !pip install zipfile
# !pip install kaggle
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/61.0 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 819.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 3.3 MB/s eta 0:00:04
#     --------------------------------------- 0.2/11.6 MB 2.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/11.6 MB 2.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.6/11.6 MB 3.3 MB/s eta 0:00:04
#    -- ------------------------------------- 0.7/11.6 MB 3.4 MB/s eta 0:00:04
#    -- ------------------------------------- 0.8/11.6 MB 3.5 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/11.6 MB 3.1 MB/s eta 0:00:04
# ...

# %%
import pandas as pd
import zipfile
import kaggle

# %%
# !kaggle datasets download -d saimondahal/life-expectancy-trends-for-males-and-females
# Out:
#   0%|          | 0.00/263k [00:00<?, ?B/s]
# 100%|██████████| 263k/263k [00:00<00:00, 306kB/s]
# 100%|██████████| 263k/263k [00:00<00:00, 306kB/s]
# ...

# %%
zipfile_name = 'life-expectancy-trends-for-males-and-females.zip'
with zipfile.ZipFile(zipfile_name, 'r') as file:
    file.extractall()

# %%
data = pd.read_csv('life_expectancy.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17003 entries, 0 to 17002
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              17003 non-null  int64
#  1   Country                 17003 non-null  object
#  2   Country Code            17003 non-null  object
#  3   Year                    17003 non-null  int64
#  4   Female Life Expectancy  17003 non-null  float64
#  5   Male Life Expectancy    17003 non-null  float64
#  6   Population              17003 non-null  float64
#  7   Life Expectancy Gap     17003 non-null  float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 1.0+ MB

# %%
data.shape
# Out:
# (17003, 8)

# %%
data
# Out:
#        Unnamed: 0      Country Country Code  Year  Female Life Expectancy  \
# 0               0     Abkhazia     OWID_ABK  2015               66.168444
# 1               1  Afghanistan          AFG  1950               28.400000
# 2               2  Afghanistan          AFG  1951               28.600000
# 3               3  Afghanistan          AFG  1952               29.100000
# 4               4  Afghanistan          AFG  1953               29.600000
# ...           ...          ...          ...   ...                     ...
# 16998       18403     Zimbabwe          ZWE  2017               63.000000
# 16999       18404     Zimbabwe          ZWE  2018               63.600000
# 17000       18405     Zimbabwe          ZWE  2019               63.700000
# 17001       18406     Zimbabwe          ZWE  2020               63.900000
# 17002       18407     Zimbabwe          ZWE  2021               62.000000
#
#        Male Life Expectancy    Population  Life Expectancy Gap
# ...

# %%
data.Country.value_counts()
# Out:
# Country
# Lebanon                        72
# Rwanda                         72
# Nepal                          72
# Netherlands                    72
# New Caledonia                  72
#                                ..
# French Southern Territories     1
# Christmas Island                1
# Cocos Islands                   1
# Pitcairn                        1
# Abkhazia                        1
# Name: count, Length: 247, dtype: int64

# %%
data.Year.value_counts()
# Out:
# Year
# 2015    247
# 1950    236
# 2001    236
# 2000    236
# 1999    236
#        ...
# 1972    236
# 1971    236
# 1970    236
# 1969    236
# 2021    236
# Name: count, Length: 72, dtype: int64
